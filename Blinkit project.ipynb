# %% [markdown]
# # Day 1: Introduction to Python for Data Analytics
# Welcome to the world of data analytics with Python!
#
# ### Why Python?
# - Easy to learn and read
# - Large ecosystem: NumPy, Pandas, Matplotlib, Seaborn
# - Open source and community-driven
# - Preferred choice in Data Science & Machine Learning

# %% [markdown]
# ##  MULTILINE COMMENTS

# %%
# HEY THERE'THIS IS COMMENT
# this is called comment

# %% [markdown]
# ## VARIABLES
# -In c and JAVA, you first declare then use but as python is dynamically typed hence we can use it directly.  <br>Variables do not need to be declared with any particular type, and can even change type after they have been set.

# %%
a = 456
sales=20000
name = "krishna"
print(sales)
# Out:
# 20000

# %% [markdown]
# ### Variables Names

# %%
A = " rakesh"
B = "ganesh"
print(A,B)
# Out:
#  rakesh ganesh

# %%
x_23 = "suraj",23
print(x_23)
# Out:
# ('suraj', 23)

# %% [markdown]
# #### Different Ways To Assign Values

# %%
a = 255
print(a)
# Out:
# 255

# %%
sale,profit,quantity = 1,55,23

# %%
profit= sale = quantity = 888

# %% [markdown]
# #### Python is  case sensitive

# %% [markdown]
# ## RESERVE WORDS

# %%
False       await       else        import      pass
None        break       except      in          raise
True        class       finally     is          return
and         continue    for         lambda      try
as          def         from    None         
ocalw       while
assert      del         global          
 with
async       elif        if          or          yield
